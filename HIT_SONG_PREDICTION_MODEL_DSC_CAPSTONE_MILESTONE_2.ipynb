# %% [markdown]
# # Jamar_Sanders_DSC_570_Capstone_Milestone_2_Hit_Song_Prediction_Model

# %% [markdown]
# # Stakeholders/Contributors
#
# Jamar Sanders &
# Professor Michelle Bennett

# %% [markdown]
# # DATA_SCIENCE_COLLEGE_OF_ENGINEERING_AND_TECHNOLOGY
#
#
#
#
# ​![image.png](attachment:image.png)

# %% [markdown]
# # Problem Statement
#
# The SpectroModel app must include a model where users' skippability rates are predicted and while using the features of a popular song, determine how to predict a song's popularity hit potential.

# %% [markdown]
# # Hypotheses
#
# Hypothesis:
# ​![image.png](attachment:image.png)
#
# R values will determine how features of a hit song deem a song a hit and predict what features are ranked highest.
#
# Null Hypotheseis:
# ![image.png](attachment:image.png)

# %% [markdown]
# Results:

# %% [markdown]
# # Project Overview and Synopsis
#
#
# The Model below will complete the steps needed to implement the prediction analyses needed for the application to be successful.
#
# SpectroModel Enterprises was created because there are no hit song prediction models that exist to boost streams and ensure all artists have a scientific and innovative way to understand how they can improve their music and marketing schemes. In one's creations, they usually work to become better through practice that may be difficult and tedious and the need for instant prediction of chart success on Billboards and other charting platforms is major in today's industry. After conducting research in Nielsen Soundscan articles and hip - hop etc. streaming platforms, one would determine that many artists are not in the position they want to be in because they are missing the technolpogy and resources that teach them what they need to know about business and the art they create in music andd other mediums of the industry.
#
# The SpectroModel Enterprises team conducted research that took months and eventyually years in a longuitudinal study that collected 8 million songs from YouTube's database, amlroe form Spotify, Apple, Amazon Prime etc. using Kaggle and Digital Signal Processing (DSP) to scrape the web and analyze millions (175 million) songs to create the most accurate model on the market SpectroModel Enterprises (ENT.) used and will use coding methods, data collection methods, and analyses methods to determine how best to implement the business model. Data is cleaned using DSP and an integrative debelopment environment for storing all datasets and analyses results from the app. From the research it was determined that what make's an artists stand out on charts and separate themselves from the average artists, or conscious artists is their marketing efforts and undertsnading of how computers undertand music and how people do. Algorithmic research and psychology combined prove that it takes more than a great song, but the understanding of what makes them. In the SpectroModel Streaming Analysis project, the results showed that their were a few outliers that ranked above all. On YouTube, the highest charting artosts were Drake, Travis Scott and Cardi B. They are known for their wild performances, melodic music, schematics in marketing and radio hit production and more. MIllions to billions of streams come from research and not just talent. The R values below show what features rank highest for each genre of music and what features determine hits and what detrmines a song's skippability rate. Loudness, Acousticness, Danceability, Energy, and Explicitness rank with loudness being the highest measure of success. A song's loudness is its ability to be played lpudly without there being any irritation of the biological person with acoustic oscillations having a positive (valence) effect on the listeners. Data in SpectroModel will be vusalized using Analyses reports, a visual dahsboard that users may customize, charts and graphs, along with spectograms that display a song's visual aesthetic such as synaesthesia does. The researcher's synaesthesia was the inspration for this feature. This will be a regression model that preidicst a song's popularity and the methods used to interpret the results are various forms of reports for users to digest the insights.
#
# SpectroModel will be a multimodal platform with analyses, research, studio correction, readings and science-backed technology that solve the need for all artists to understand that engineers, musicians, psychologists, marketers, philosophers, historians, mathemeticians and statisticians all play a role in an artists's success.
#
# SpectroModel Enterprises (SpectroModel Ent.) is a next-generation creative technology company specializing in artificial intelligence, digital signal processing (DSP), multimedia production, artist-centric business tools, and immersive 3D experiences. The platform integrates advanced machine learning with a creator-friendly interface, delivering an ecosystem where audio, video, data, business operations, and interactive visualizations converge into a unified digital environment. SpectroModel is designed for musicians, producers, digital artists, educators, researchers, and creative entrepreneurs. The company’s mission is to empower creators with intelligent tools that simplify workflows, enhance creative output, and open new pathways for monetization, audience engagement, and professional growth.

# %% [markdown]
# Latex Math Equations:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt

# Visualization function
def plot_ols(X, y, model, title):
    y_pred = model.predict(X)
    residuals = y - y_pred

    plt.figure(figsize=(12, 8))

    plt.subplot(2, 2, 1)
    plt.scatter(y, y_pred)
    plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=2)
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.title(f"{title} - Actual vs Predicted")

    plt.subplot(2, 2, 2)
    plt.scatter(y_pred, residuals)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel('Predicted')
    plt.ylabel('Residuals')
    plt.title(f"{title} - Residuals vs Predicted")

    plt.subplot(2, 2, 3)
    sns.histplot(residuals, kde=True)
    plt.title(f"{title} - Residuals Histogram")

    plt.subplot(2, 2, 4)
    sm.qqplot(residuals, line='45', ax=plt.gca())
    plt.title(f"{title} - QQ Plot")

    plt.tight_layout()
    plt.show()

# Load data
data = pd.read_csv("/workspaces/Hit_Song_Prediction_Model/tracks.csv")  # Replace with your file path
numeric_data = data.select_dtypes(include='number').copy()
numeric_data.dropna(inplace=True)

# %% [markdown]
# # Results:
# The results here show that the results are statistically significant as per the p values. The R ^ 2 values show that Valence is .432 and that is high for a song feature when accounting for all instances of song track in the dataset at 586,772,  determining if a song is a hit on pop charts, so this song has a great valence (positive energy) score and is indicative of a hit song and it is correlated with the song's popularity. It may not be the single factor that causes the song to be a hit on pop charts, but it ranks high on the hierarchy of features that do. That means that the valence in the song may be a contemporary popular (pop) song, hip hop, rock song, electric, techno song with an acoustic theme of love, joy, elation, or happiness etc.

# %% [markdown]
# Latex Math Equations:
# ![image.png](attachment:image.png)

# %%
target = 'valence'
X = numeric_data.drop(columns=[target])
y = numeric_data[target]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
plot_ols(X, y, model, f"{target} ~ All Other Variables")
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                valence   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.432
# Method:                 Least Squares   F-statistic:                 3.184e+04
# Date:                Mon, 07 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:43:51   Log-Likelihood:             1.2891e+05
# No. Observations:              586672   AIC:                        -2.578e+05
# Df Residuals:                  586657   BIC:                        -2.576e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.3353      0.003    -99.698      0.000      -0.342      -0.329
# ...

# %% [markdown]
# # Results
#
# The results here show that the results are not statistically significant as per the p values. The R ^ 2 values show that time signature is .066 and that is low for a song feature determining if a song is a hit on pop charts, so this feature of the song has a poor time signature (rhythm) score when accounting for all instances of song track in the dataset at 586,772, and is not indicative of a hit song and it is not correlated with the song's popularity. It may not be the single factor that causes the song to not be a hit on pop charts, but it ranks low on the hierarchy of features that do. That means that the time signature in the song may be purposely inverted, off beat to help an artists keep up with the instrumental and avoid rushing their words, a song by an unsophisticated or developed artist, or an audio file that may not be of a song at all. That may not be the case for this, but these are some reasons a time signature may rank low in a song's features.

# %% [markdown]
# # Latex Math Equations:
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %%
target = 'time_signature'
X = numeric_data.drop(columns=[target, 'valence'])
y = numeric_data[target]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
plot_ols(X, y, model, f"{target} ~ All Except Valence")
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         time_signature   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.066
# Method:                 Least Squares   F-statistic:                     3193.
# Date:                Mon, 07 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:44:10   Log-Likelihood:            -3.7338e+05
# No. Observations:              586672   AIC:                         7.468e+05
# Df Residuals:                  586658   BIC:                         7.469e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                3.5742      0.006    558.810      0.000       3.562       3.587
# ...

# %% [markdown]
# # Results
#
# The results here show that the results are not statistically significant as per the p values. The R ^ 2 values show that time duration is .038 and that is low for a song feature when accounting for all instances of song track in the dataset at 586,772, determining if a song is a hit on pop charts, so this song has a poor duration (time) score and is not indicative of a hit song and it is not correlated with the song's popularity. It may not be the single factor that causes the song to not be a hit on pop charts, but it ranks low on the hierarchy of features that do. That means that the duration may be too long for a pop chart to rank it high since the average song length today  has gotten shorter since the start of the century. The average now is three minutes for most pop, hip hop, rock etc. songs since people prefer short bursts of dopamine and are conditioned by social media, medicine, food, drugs, anxiety, and otehr factors.

# %% [markdown]
# Latex Math Equations:
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
target = 'duration_ms'
X = numeric_data.drop(columns=[target, 'valence', 'time_signature'])
y = numeric_data[target]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
plot_ols(X, y, model, f"{target} ~ All Except Valence & Time Signature")
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            duration_ms   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     1937.
# Date:                Mon, 07 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:44:24   Log-Likelihood:            -7.7134e+06
# No. Observations:              586672   AIC:                         1.543e+07
# Df Residuals:                  586659   BIC:                         1.543e+07
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             3.033e+05   1690.028    179.469      0.000       3e+05    3.07e+05
# ...

# %% [markdown]
# # Results
#
# The results here show that the results are statistically significant as per the p values. The R ^ 2 values show that energy is .748 and that is high for a song feature when accounting for all instances of song track in the dataset at 586,772, determining if a song is a hit on pop charts, so this song has a great energy (upbeat/lowbeat) score and is indicative of a hit song and it is correlated with the song's popularity. It may not be the single factor that causes the song to be a hit on pop charts, but it ranks high on the hierarchy of features that do. That means that the energy of the song is made for people at home with family partying, at clubs where people show up to jump and scream, stadiums, arenas, and may be techno, electric, jhip-hop, rock n roll, electronic, funk etc.

# %% [markdown]
# Latex Math Equations:
#
# ![image.png](attachment:image.png)

# %%
target = 'energy'
X = numeric_data.drop(columns=[target, 'valence', 'time_signature', 'duration_ms'])
y = numeric_data[target]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
plot_ols(X, y, model, f"{target} ~ All Except Valence, Time Signature, Duration")
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 energy   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.748
# Method:                 Least Squares   F-statistic:                 1.584e+05
# Date:                Mon, 07 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:44:37   Log-Likelihood:             3.8081e+05
# No. Observations:              586672   AIC:                        -7.616e+05
# Df Residuals:                  586660   BIC:                        -7.615e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.8672      0.001    668.510      0.000       0.865       0.870
# ...

# %% [markdown]
# # Results
#
# The results here show that the results are statistically significant as per the p values. The R ^ 2 values show that danceability (oscillating factor that causes human movement) is .194 and that is average and good for a song feature when accounting for all instances of song tracks in the dataset at 586,772, determining if a song is a hit on pop charts, so this song has an average danceability score and is indicative of a hit song and it is correlated with the song's popularity. It may not be the single factor that causes the song to be a hit on pop charts, but it ranks high on the hierarchy of features that do. That means that the danceability is for people who are going to lisyten for getting a mood of excitement and they may be with someone who they will dance with at a romantic outing etc. Songs that make one dance with an average danceability score are usually for pop, soulful, and melodic funk with not much club impact.

# %% [markdown]
# Latex Math Equations:
# ![image.png](attachment:image.png)

# %%
target = 'danceability'
X = numeric_data.drop(columns=[target, 'valence', 'time_signature', 'duration_ms', 'energy'])
y = numeric_data[target]

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
plot_ols(X, y, model, f"{target} ~ All Except Valence, Time Signature, Duration, Energy")
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           danceability   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                 1.410e+04
# Date:                Mon, 07 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:44:48   Log-Likelihood:             2.8391e+05
# No. Observations:              586672   AIC:                        -5.678e+05
# Df Residuals:                  586661   BIC:                        -5.677e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.7194      0.001    595.410      0.000       0.717       0.722
# ...

# %% [markdown]
# # Results
#
# The results here show that the results are statistically significant as per the p values. The R ^ 2 values show that popularity of a song after features have been included in the song is .205 and that is average and good for a popularity when accounting for all instances of song tracks in the dataset at 586,772 so this song has an average popularity score and is indicative of a hit song. This is a song that will rank on billbard pop charts etc. The song is not the mega hit a Beyonce caliber artist is known for, but more on the scale of a Sabrina Carpenter.

# %% [markdown]
# Latex Math Equations:
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import statsmodels.api as sm

# Load your dataset
df = pd.read_csv('/workspaces/Hit_Song_Prediction_Model/tracks.csv')  # Replace with your actual dataset path

# Define the target variable (popularity) and the predictor variables
X = df[['danceability', 'explicit', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'tempo']]  # Predictor variables
y = df['popularity']  # Target variable

# Add a constant to the predictor variables (for the intercept term)
X = sm.add_constant(X)

# Perform the OLS regression
model = sm.OLS(y, X)
results = model.fit()

# Print the regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                 1.517e+04
# Date:                Mon, 07 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:44:55   Log-Likelihood:            -2.4726e+06
# No. Observations:              586672   AIC:                         4.945e+06
# Df Residuals:                  586661   BIC:                         4.945e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               37.5226      0.161    233.475      0.000      37.208      37.838
# ...

# %% [markdown]
# # Results
#
# The results here show that the ranking order of a song's popularity after analyzing and training a dataset of 586,772 songs. The 1. loudness, 2.  energy, 3. explicitness, 4. danceability, and 5. key of the song are the top five features that determine a song's popularity. What that means is that pop listeners want to listen while surrounded by speakers, lights, drinks, games, and people shouting the lyrics to their favorite song while not worrying about the past and the burdens in life. It also means that a song's energy (upbeat/lowbeat) feature ranks high when considering streaming and album sales.  A song can be explicit or not and still be a hit but that alone does not determine the song's hit potential. Speechiness may rank last because the amount of words being said ber bar in a song is the opposite of what predicts and foreshadows a song's popularity. Artists and marketing teams who are aiming for a hit, must ensure that people get an experience that is memorable that gets them dancing. The results may be misleading because the acousticness may say to one that this is not important, but the acousticness is the song's natural instrumentals that are used. Most music is used and made on digital technology, so that does not tell the full story. Research states that classical music, blues, jazz, soul, funk are great genres, but may and will almost always not become hits on pop charts, but only because of how they are made.

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('/workspaces/Hit_Song_Prediction_Model/tracks.csv')  # Replace with your actual dataset path

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])

# Calculate correlation matrix
correlation_matrix = numeric_df.corr()

# Display the correlation matrix
print(correlation_matrix)

# Show the correlation of all variables with 'popularity'
if 'popularity' in numeric_df.columns:
    print(correlation_matrix['popularity'])
# Out:
#                   popularity  duration_ms  explicit  danceability    energy  \
# popularity          1.000000     0.027681  0.211758      0.187000  0.302315
# duration_ms         0.027681     1.000000 -0.016747     -0.120371  0.024825
# explicit            0.211758    -0.016747  1.000000      0.150229  0.123076
# danceability        0.187000    -0.120371  0.150229      1.000000  0.241563
# energy              0.302315     0.024825  0.123076      0.241563  1.000000
# key                 0.015299     0.004626  0.010932      0.018824  0.036294
# loudness            0.327028     0.000337  0.134603      0.251436  0.764735
# mode               -0.033655    -0.027610 -0.051754     -0.044719 -0.065246
# speechiness        -0.047357    -0.125771  0.102258      0.199310 -0.053506
# acousticness       -0.370882    -0.064434 -0.149018     -0.242951 -0.715412
# instrumentalness   -0.236487     0.069278 -0.067520     -0.225900 -0.195839
# ...

# %%
import statsmodels.api as sm

# Define the target variable (popularity) and the predictor variables
X = df[['danceability', 'explicit', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'tempo']]  # Predictor variables
y = df['popularity']  # Target variable

# Add a constant to the predictor variables (for the intercept term)
X = sm.add_constant(X)

# Perform the OLS regression
model = sm.OLS(y, X)
results = model.fit()

# Print the regression results
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.205
# Method:                 Least Squares   F-statistic:                 1.517e+04
# Date:                Mon, 07 Apr 2025   Prob (F-statistic):               0.00
# Time:                        14:45:07   Log-Likelihood:            -2.4726e+06
# No. Observations:              586672   AIC:                         4.945e+06
# Df Residuals:                  586661   BIC:                         4.945e+06
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               37.5226      0.161    233.475      0.000      37.208      37.838
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('/workspaces/Hit_Song_Prediction_Model/tracks.csv')  # Replace with your actual dataset path

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation between 'popularity' and the selected variables
correlation_with_popularity = numeric_df[['popularity', 'loudness', 'acousticness', 'energy', 'danceability', 'explicit']].corr()

# Display the correlation values of the selected variables with 'popularity'
print(correlation_with_popularity['popularity'])
# Out:
# popularity      1.000000
# loudness        0.327028
# acousticness   -0.370882
# energy          0.302315
# danceability    0.187000
# explicit        0.211758
# Name: popularity, dtype: float64

# %% [markdown]
# # The Different Variation in Popular (POP) Music
#
# Loudness: Refers to the overall volume or amplitude of the audio in a track. It typically indicates how loud or soft the song sounds. Higher values indicate a louder track, while lower values suggest a quieter one.
#
# Acoustics: This relates to the qualities of the sound in a recording, such as how natural, clean, or spacious the music feels. It can be influenced by things like the use of reverb, the presence of background noise, or the clarity of the recording.
#
# Energy: Represents the intensity and activity level of a song. High energy tracks often have fast tempos, loud volumes, and intense instruments, while lower energy songs tend to be more relaxed, slower, and quieter.
#
# Danceability: Measures how suitable a song is for dancing, considering rhythm, tempo, beat consistency, and overall groove. A higher danceability score typically means the song has a rhythm that encourages movement, while lower scores suggest it might not be as rhythmic or suitable for dancing.
#
# Explicitness: Indicates whether a song contains explicit content, such as strong language or adult themes. A higher value suggests that the song may include profane language or other mature content, while lower values suggest a more family-friendly track.

# %% [markdown]
# # Results
#
# The results here show that the ranking order of a song's popularity after analyzing and training a dataset of 586,772 songs. The 1. loudness, 2.  energy, 3. explicitness, and 4. danceability, of the song are the top 4 features that determine a song's popularity. What that means is that pop listeners want to listen while surrounded by speakers, lights, drinks, games, and people shouting the lyrics to their favorite song while not worrying about the past and the burdens in life. It also means that a song's energy (upbeat/lowbeat) feature ranks high when considering streaming and album sales.  A song can be explicit or not and still be a hit but that alone does not determine the song's hit potential. Speechiness may rank last because the amount of words being said per bar in a song is the opposite of what predicts and foreshadows a song's popularity. Artists and marketing teams who are aiming for a hit, must ensure that people get an experience that is memorable that gets them dancing. The results may be misleading because the acousticness may say to one that this is not important, but the acousticness is the song's natural instrumentals that are used. Most music is used and made on digital technology, so that does not tell the full story. Research states that classical music, blues, jazz, soul, funk are great genres, but may and will almost always not become hits on pop charts, but only because of how they are made. The acousticness is the song's sonic features in relation to the mediums that were used to create them. It can mean more than it may show here as the acoustic genres are the ones that have stood the test of time longer than modern day music. Popular here means songs that provide lasting joy and memories, but may not make one think much and create stronger internal associations that the acoustic genres do.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset
df = pd.read_csv('/workspaces/Hit_Song_Prediction_Model/tracks.csv')  # Replace with your actual dataset path

# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=['number'])

# Calculate the correlation between 'popularity' and the selected variables
correlation_with_popularity = numeric_df[['popularity', 'loudness', 'acousticness', 'energy', 'danceability', 'explicit']].corr()

# Create a bar plot for the correlation values with popularity
plt.figure(figsize=(10, 6))
sns.barplot(x=correlation_with_popularity.index[1:], y=correlation_with_popularity['popularity'][1:], palette='viridis')

# Customize the graph
plt.title('Correlation Between Popularity and Key Features', fontsize=16)
plt.xlabel('Features', fontsize=12)
plt.ylabel('Correlation Coefficient', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_1652/868046846.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation_with_popularity.index[1:], y=correlation_with_popularity['popularity'][1:], palette='viridis')

# %% [markdown]
# # References:
# ACM. (2021). ACM code of ethics and professional conduct. https://www.acm.org
#
# Amazon Web Services. (2024). AWS documentation. https://docs.aws.amazon.com
#
# Amershi, S., Weld, D., Vorvoreanu, M., Fourney, A., Nushi, B., Collisson, P., Suh, J., Iqbal, S., Bennett, P. N., Inkpen, K., & Horvitz, E. (2020). Guidelines for human–AI interaction. CHI Conference on Human Factors in Computing Systems, 1–13.
#
# Apple Inc. (2024). Apple Music API documentation. https://developer.apple.com
#
# Ay, Y. E. (n.d.). Spotify dataset 1921–2020, 600k+ tracks [Data set]. Kaggle. https://www.kaggle.com/datasets/yamaerenay/spotify-dataset-19212020-600k-tracks
#
# Bass, L., Clements, P., & Kazman, R. (2013). Software architecture in practice (3rd ed.). Addison-Wesley.
#
# Bishop, C. M. (2006). Pattern recognition and machine learning. Springer.
#
# Breiman, L. (2001). Random forests. Machine Learning, 45(1), 5–32. https://doi.org/10.1023/A:1010933404324
#
# Casey, M. A., Veltkamp, R., Goto, M., Leman, M., Rhodes, C., & Slaney, M. (2008). Content-based music information retrieval. Proceedings of the IEEE, 96(4), 668–696. https://doi.org/10.1109/JPROC.2008.916370
#
# Flanagan, D. (2020). JavaScript: The definitive guide (7th ed.). O’Reilly Media.
#
# Fowler, M. (2018). Refactoring: Improving the design of existing code (2nd ed.). Addison-Wesley.
#
# Gamma, E., Helm, R., Johnson, R., & Vlissides, J. (1994). Design patterns: Elements of reusable object-oriented software. Addison-Wesley.
#
# GeeksforGeeks. (2025, January 16). Linear regression (Python implementation). https://www.geeksforgeeks.org/
# linear-regression-python-implementation/
#
# Goodfellow, I., Bengio, Y., & Courville, A. (2016). Deep learning. MIT Press.
#
# Grinberg, M. (2018). Flask web development (2nd ed.). O’Reilly Media.
#
# Google. (2025). Google Colaboratory. Retrieved May 7, 2025, from https://colab.research.google.com/
#
# Hastie, T., Tibshirani, R., & Friedman, J. (2009). The elements of statistical learning (2nd ed.). Springer.
#
# International Federation of the Phonographic Industry. (2023). Global music report.
#
# James, G., Witten, D., Hastie, T., & Tibshirani, R. (2021). An introduction to statistical learning (2nd ed.). Springer.
#
# Jupyter Project. (2024). Jupyter notebook documentation. https://jupyter.org
#
# Katsamakas, E., & Pavlov, O. (2020). AI and business model innovation: Leveraging the AI feedback loop. Journal of Business Models, 8(2), 22–30.
#
# Kimball, R., & Ross, M. (2013). The data warehouse toolkit (3rd ed.). Wiley.
#
# Kleppmann, M. (2017). Designing data-intensive applications. O’Reilly Media.
#
# Kumar, S., Lim, M. W., Sivarajah, U., & Kaur, J. (2022). Artificial intelligence and blockchain integration in business: Trends from a bibliometric-content analysis. Information Systems Frontiers.
#
# Larose, C. D., & Larose, D. T. (2019). Data science using Python and R. John Wiley & Sons, Inc.
#
# McKinsey & Company. (2022). Advanced analytics in the music industry.
#
# Meredith, D., & Devaney, J. (2025). Editorial. Journal of New Music Research, 54(1), 1–2. https://doi.org/10.1080/09298215.2025.2600216
#
# Merlo, T. R. (2025). From data to decision: Unraveling the impact of analytics and AI in the business decision-making process. In World Scientific Publishing Co. Pte. Ltd.
#
# Microsoft. (2022). Excel VBA documentation. Microsoft Learn.
#
# Microsoft Azure. (2024). Azure documentation. https://learn.microsoft.com/azure
#
# Morris, K. (2016). Infrastructure as code. O’Reilly Media.
#
# Morris, T. P., White, I. R., & Crowther, M. J. (2022). Using simulation studies to evaluate statistical methods. Statistics in Medicine, 41(9), 1611–1629.
#
# Müller, M. (2015). Fundamentals of music processing. Springer.
#
# Nallamala, S. H., Bajjuri, U. R., Anandarao, S., Prasad, D. D., & Mishra, P. (2020, December). A brief analysis of collaborative and content-based filtering algorithms used in recommender systems. IOP Conference Series: Materials Science and Engineering, 981(2), 022008. https://doi.org/10.1088/1757-899X/981/2/022008
#
# National Institute of Standards and Technology. (2020). Security and privacy controls for information systems and organizations (SP 800-53 Rev. 5).
#
# Ni, J. (2018). Amazon Review Data (2018) [Data set]. University of California, San Diego. Retrieved from https://nijianmo.github.io/amazon/index.html
#
# Ni, J., Li, J., & McAuley, J. (2019). Justifying recommendations using distantly-labeled reviews and fine-grained aspects. In Proceedings of the 2019 Conference on Empirical Methods in Natural Language Processing (EMNLP). https://arxiv.org/abs/1911.06827
#
# Nielsen, J. (1994). Usability engineering. Morgan Kaufmann.
#
# Node.js Foundation. (2024). Node.js documentation. https://nodejs.org
#
# Norman, D. A. (2013). The design of everyday things (Revised ed.). Basic Books.
#
# OWASP Foundation. (2023). OWASP top 10 web application security risks. https://owasp.org
#
# Peeters, G. (2004). A large set of audio features for sound description. IRCAM.
#
# Project Management Institute. (2021). A guide to the project management body of knowledge (PMBOK® Guide) (7th ed.).
#
# React Team. (2024). React documentation. https://react.dev
#
# Ries, E. (2011). The lean startup. Crown Business.
#
# Shewhart, W. A., & Wilks, S. S. (Eds.). (n.d.). Wiley series in probability and statistics. Wiley.
#
# Silberschatz, A., Korth, H. F., & Sudarshan, S. (2020). Database system concepts (7th ed.). McGraw-Hill.
#
# Singh, H. (2024, December 20). 6 assumptions of linear regression. https://www.analyticsvidhya.com/blog/2016/07/deeper-regression-analysis-assumptions-plots-solutions/
#
# SpectroModel Enetrprises (ENT.) (2026.) spectromodel.com/
#
# Spotify for Developers. (2024). Spotify Web API documentation. https://developer.spotify.com
#
# Srifi, M., Oussous, A., Ait Lahcen, A., & Mouline, S. (2020). Recommender systems based on collaborative filtering using review texts—A survey. Information, 11(6), 317. https://doi.org/10.3390/info11060317
#
# Stallings, W. (2017). Cryptography and network security (7th ed.). Pearson.
#
# United States Patent and Trademark Office. (2024). Manual of patent examining procedure (MPEP). https://www.uspto.gov
#
# Ware, C. (2013). Information visualization: Perception for design (3rd ed.). Morgan Kaufmann.
#
# Wen, L., Ye, X., & Gao, L. (2020). A new automatic machine learning based hyperparameter optimization for workpiece quality prediction. Measurement and Control, 53(7–8), 1257–1265. https://doi.org/10.1177/0020294020932320
#
# World Intellectual Property Organization. (2023). Intellectual property handbook.
#
# Yu, C. H., Lee, H. S., Lara, E., & Gan, S. (2018). The ensemble and model comparison approaches for big data analytics in social sciences. Practical Assessment, Research & Evaluation, 23(17), 1–16. https://doi.org/10.7275/7jph-2f69
#
# Zhang, Z., Peng, T., & Shen, K. (2020, February). Overview of collaborative filtering recommendation algorithms. IOP Conference Series: Earth and Environmental Science, 440(2), 022063. https://doi.org/10.1088/1755-1315/440/2/022063
